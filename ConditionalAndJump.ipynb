// %% [markdown]
// ### Conditional and Jump Statements
//
// * If Statement
// * If Else
// * If Else-If Else Ladder
// * If as expression
// * Match statement
// * Match as expression
// * return statement
// * try-catch-finally for Exception Handling

// %%
//If statement
val num: Int=10

if(num == 10){
    println("Number is 10")
}

//If else statement

if(num == 10){
    println("Number is 10")
}else{
    println("Number is not 10")
}

//If else-if else ladder

if(num == 10){
    println("Number is 10")
} else if (num == 20){
    println("Number is 20")
} else {
    println("Number is something else")
}

//If as expression

val result: String = if(num == 10) "Number is 10" : "Number is something else"

//match statement

num match {
    case 10 => println("Number is 10")
    case 20 => println("Number is 20")
    case _ => println("Number is something else")
}

//match as expression

val matchResult: String = num match {
    case 10 => "Number is 10"
    case 20 => "Number is 20"
    case _ => "Number is something else"
}

//return statement

def multiply(num1: Int, num2: Int): Int {
    return num1 * num2;
}

//try-catch-finally statement

try {
    val result = 89/0
} catch {
    case e: ArithmeticException => println("Division by zero not allowe")
} finally {
    println("Finally block will always execute")
}
